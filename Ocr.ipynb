# %% [markdown]
# Set the subscription_key and endpoint values below to the corresponding values from the provided Azure Vision Service
#
# The image_url can be changed to any accessible online image.

# %%
subscription_key =""
endpoint = ""
image_url = "https://raw.githubusercontent.com/cloudacademy/azure_image_speech/main/assets/cafe.jpg"

# %% [markdown]
# When run the below code will connect to the vision service and use it to analyse the image specified by the image_url specified above.
#
# It will then render the image and overlay and recognisable text.

# %%
import requests

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from PIL import Image
from io import BytesIO

# OCR endpoint
ocr_url = endpoint.rstrip("/") + "/computervision/imageanalysis:analyze"
params = {
    "api-version": "2024-02-01",
    "features": "read",
}

# Download image
content = requests.get(image_url).content

headers = {
    "Ocp-Apim-Subscription-Key": subscription_key,
    "Content-Type": "application/octet-stream"
}

# Call OCR
response = requests.post(ocr_url, headers=headers, params=params, data=content)
response.raise_for_status()

analysis = response.json()

# Extract words
word_infos = []
for block in analysis.get("readResult", {}).get("blocks", []):
    for line in block.get("lines", []):
        for word in line.get("words", []):
            word_infos.append(word)

word_infos

# Display image and overlay OCR text
plt.figure(figsize=(10, 10))
image = Image.open(BytesIO(content))
ax = plt.imshow(image, alpha=0.5)

for word in word_infos:
    polygon = [(p["x"], p["y"]) for p in word["boundingPolygon"]]
    text = word["text"]

    patch = Polygon(polygon, closed=True, fill=False, linewidth=2, color="y")
    ax.axes.add_patch(patch)

    x, y = polygon[0]
    plt.text(x, y, text, fontsize=12, weight="bold", va="top")

plt.axis("off")
plt.show()
